# %% [markdown]
# 🎉🎂🎉 Birthday Posts Exploration
# Motivation
# It’s useful for a brand to know a beauty blogger’s birthday so that they can do timely birthday-specific outreach. For example, brands can engage some of their top bloggers with gift makeup sets.
#
# Project
# -
# We would like for you to visualize and explore our social media posts data, with a focus on the posts that mention the words “my birthday.” Here are some questions to guide your exploration. There is no need to answer all or any of these questions if you want to explore the data in another way.
# How many birthday posts does a user post on average? If a user posts multiple posts, are they all clustered around a certain month or day?
# How are birthday mentions different across different channels?
# How many birthday mentions indicate an age? (i.e. “my 30th birthday”)
# Develop a way to guess a user’s birth date (month and/or day and/or year) using this text data.
# What are some common themes in these birthday posts? (Are they about cake, gifts, resolutions, or something else?)
# As you begin exploring the data, remember to record your thought process and show your work in some way (i.e. Jupyter notebook, d3.js, etc).
# Data
# This csv file includes social media posts from our influencer database posted between Dec 2016 and Dec 2017. (~28 MB;  ~66k posts) Tip: use pandas to open this file in python.

# %%
import pandas as pd
import re

# %%
posts = pd.read_csv("birthday_posts.csv")

# %% [markdown]
# Notes go here

# %%
def birthday_thing(text):
    if "birthday" in text.lower():
        return True
    else:
        return False

# %%
posts[posts['user_id'] == "zoepower"]
# Out:
#         channel   user_id publish_date  \
# 2316  PINTEREST  zoepower   2017-10-19
# 9265  PINTEREST  zoepower   2017-10-23
#
#                                               post_link  \
# 2316  https://www.pinterest.com/pin/168110998574733971/
# 9265  https://www.pinterest.com/pin/168110998574759832/
#
#                                                    text
# 2316  Morning folks! Im excited to say we are headin...
# 9265  Hello folks! Im celebrating my birthday today ...

# %%
#how many BIRTHDAY posts does a USER post on average ? this means ok how many unique users, and how  



# count user ids, take the mean of a column (doesnt really matter which one)


posts.groupby('user_id').count()['text'].mean()

#.reset_index().sort_values('text', ascending=False)['text'].mean()

# a = posts['user_id'] == "UCeeIqJdljsFxtEoQtwANFQw"
# posts[a]['text'].apply(birthday_thing)
# Out:
# 1.8433724993808647

# %% [markdown]
# If a user posts multiple posts, are they all clustered around a certain month or day?

# %%
#If a user posts multiple posts, are they all clustered around a certain month or day?
# so to predict a birthday, if a user has multiple posts they will liekly be posting w/ the birthday up UNTIL the actual birthday

def birthday_today(text):
    if "birthday" in text.lower() and "today" in text.lower():
        return True
    else:
        return False
    
bd_today = posts['text'].astype(str).apply(birthday_today)
posts[bd_today]
# Out:
#          channel                   user_id publish_date  \
# 4      PINTEREST            hhomeschooling   2017-08-21
# 10     INSTAGRAM                  43060483   2017-07-24
# 16     INSTAGRAM                1957320951   2017-08-06
# 18      FACEBOOK           348428501940559   2017-08-14
# 19      FACEBOOK           348428501940559   2017-08-14
# 25     INSTAGRAM                1388121520   2017-08-01
# 35      FACEBOOK           173939949292193   2017-07-10
# 56       TWITTER                 317997653   2017-08-29
# 64     INSTAGRAM                 196929122   2017-08-10
# 66     INSTAGRAM                 178650179   2017-08-03
# 69     INSTAGRAM                  28766168   2017-09-20
# 71      FACEBOOK              172950671664   2017-08-26
# 78     INSTAGRAM                  24384644   2017-07-31
# 80     PINTEREST           misscosmeticblo   2017-08-20
# 83      FACEBOOK           171591009561269   2017-08-26
# 86     PINTEREST                malinbngel   2017-08-20
# 92     INSTAGRAM                   5159248   2017-08-12
# 93     INSTAGRAM                 186239981   2017-08-01
# 100     FACEBOOK           248423355282235   2017-08-10
# 124    INSTAGRAM                1430041642   2017-08-01
# 176    PINTEREST                  servedup   2017-10-24
# 185      YOUTUBE  UC39eHhTEqiBlqRbmIIYjm-g   2017-07-05
# 198    INSTAGRAM                  13692205   2017-06-27
# 214      TWITTER                1222989332   2017-08-15
# 217      TWITTER                  16300281   2017-08-10
# 233      TWITTER                2391106842   2017-10-22
# 257     FACEBOOK          1408373986090781   2017-07-10
# 258    INSTAGRAM                  13160559   2017-08-04
# 269      TWITTER                  87628316   2017-06-10
# 270    INSTAGRAM                 242444878   2017-07-27
# ...          ...                       ...          ...
# 66824  INSTAGRAM                4206540772   2017-11-21
# 66837    YOUTUBE  UCp5quhY11twFaQtZUBnbZ5A   2017-08-18
# 66839    YOUTUBE  UCp5quhY11twFaQtZUBnbZ5A   2017-09-24
# 66840    YOUTUBE  UCvrgb275ZLH07Jx31D-dxIw   2017-10-22
# 66844    YOUTUBE  UC-gljeiuxAOpxiB1j32pKpQ   2017-05-19
# 66853  INSTAGRAM                  30919212   2017-11-20
# 66857  INSTAGRAM                   6239536   2017-08-07
# 66862    TWITTER                  47073338   2017-10-28
# 66865    YOUTUBE  UCjh26H0yxqi8pU926PaQD1w   2017-04-21
# 66873    YOUTUBE  UCB1lNklQPsLT7gSWnfGZ0iA   2017-02-12
# 66874    YOUTUBE  UCfxXv_qi6UfB6Ms0sqxEmrQ   2017-07-02
# 66879    YOUTUBE  UCmINCRtFo4mw5Qaph8A24jg   2017-01-04
# 66895    YOUTUBE  UCp5quhY11twFaQtZUBnbZ5A   2017-07-21
# 66899    YOUTUBE  UCS0pvfQZhy8qYG7Bhg51h7Q   2017-11-02
# 66901    YOUTUBE  UCB1lNklQPsLT7gSWnfGZ0iA   2017-11-29
# 66902    YOUTUBE  UCamld3y9cWyPy6J-LBye-Mw   2017-10-11
# 66903    YOUTUBE  UCvrgb275ZLH07Jx31D-dxIw   2017-09-08
# 66909    YOUTUBE  UCc3gTqbskc_wGl7pFk62hpg   2017-03-13
# 66924    YOUTUBE  UCj1PZqhFiJIoMLH3cAPrsQQ   2017-06-20
# 66927    YOUTUBE  UC93Yq5migrrcOngZWmW2LSQ   2017-03-08
# 66929    YOUTUBE  UC_qmuW_i0ZuUXvGRe53Kilg   2017-03-10
# 66935    YOUTUBE  UCxFBPxpr8WSQrtBZoKDSw_Q   2017-04-02
# 66943    YOUTUBE  UCQzbLEHcCzz1bIN9tnpfCXA   2017-03-15
# 66948    YOUTUBE  UCGePwNuIDAblKzfFHUDWAxg   2017-01-22
# 66952    YOUTUBE  UCvrgb275ZLH07Jx31D-dxIw   2017-05-14
# 66955    YOUTUBE  UCvrgb275ZLH07Jx31D-dxIw   2017-07-09
# 66968    YOUTUBE  UCvrgb275ZLH07Jx31D-dxIw   2017-11-03
# 66972    YOUTUBE  UCB1lNklQPsLT7gSWnfGZ0iA   2017-03-11
# 66979    YOUTUBE  UCvrgb275ZLH07Jx31D-dxIw   2017-05-07
# 66988    YOUTUBE  UCe9oofjVfJzapRyVlt57x8Q   2017-10-22
#
#                                                post_link  \
# 4      https://www.pinterest.com/pin/426434658457849037/
# 10              https://www.instagram.com/p/BW75SA7lNkm/
# 16              https://www.instagram.com/p/BXc-ecTFTYW/
# 18     https://www.facebook.com/348428501940559/posts...
# 19     https://www.facebook.com/348428501940559/posts...
# 25              https://www.instagram.com/p/BXQ4QdfDOP1/
# 35     https://www.facebook.com/173939949292193/posts...
# 56     https://www.twitter.com/haysparkle1/status/902...
# 64              https://www.instagram.com/p/BXnkJRuFpho/
# 66              https://www.instagram.com/p/BXVME3bBZAJ/
# 69              https://www.instagram.com/p/BZQ8HsZnMHa/
# 71     https://www.facebook.com/172950671664/posts/10...
# 78              https://www.instagram.com/p/BXN3qpgl1_M/
# 80     https://www.pinterest.com/pin/349240146095049907/
# 83     https://www.facebook.com/171591009561269/posts...
# 86     https://www.pinterest.com/pin/519884350726057712/
# 92              https://www.instagram.com/p/BXs0yQ7F8fN/
# 93              https://www.instagram.com/p/BXO9HVwA_a_/
# 100    https://www.facebook.com/248423355282235/posts...
# 124             https://www.instagram.com/p/BXQEVy4hSym/
# 176     https://www.pinterest.com/pin/55591376634299120/
# 185          https://www.youtube.com/watch?v=1_tekLNN9QY
# 198             https://www.instagram.com/p/BV2gnd8nFki/
# 214    https://www.twitter.com/CaraASantana/status/89...
# 217    https://www.twitter.com/VRodriguezIII/status/8...
# 233    https://www.twitter.com/eleanorparkerwv/status...
# 257    https://www.facebook.com/1408373986090781/post...
# 258             https://www.instagram.com/p/BXYISxIhiWz/
# 269    https://www.twitter.com/CearasKitchen/status/8...
# 270             https://www.instagram.com/p/BXClPw5nBBF/
# ...                                                  ...
# 66824           https://www.instagram.com/p/Bbwk0wFgREh/
# 66837        https://www.youtube.com/watch?v=0Be5pDQb1VY
# 66839        https://www.youtube.com/watch?v=C5GRZWLd9Y8
# 66840        https://www.youtube.com/watch?v=CaYgwRJ9DL4
# 66844        https://www.youtube.com/watch?v=L132miD2o0I
# 66853           https://www.instagram.com/p/Bbs8RdgBWFG/
# 66857           https://www.instagram.com/p/BXem8g3DWdt/
# 66862  https://www.twitter.com/LiamPitts/status/92419...
# 66865        https://www.youtube.com/watch?v=4vNNgTLmq6M
# 66873        https://www.youtube.com/watch?v=DH1eAYSdlus
# 66874        https://www.youtube.com/watch?v=N7mc4ZS5ZpQ
# 66879        https://www.youtube.com/watch?v=FFGAJJA3sFU
# 66895        https://www.youtube.com/watch?v=0msZcqwvsME
# 66899        https://www.youtube.com/watch?v=KSZOA0CHFW0
# 66901        https://www.youtube.com/watch?v=Kn9FM7IMSeE
# 66902        https://www.youtube.com/watch?v=Lr67Z9zK134
# 66903        https://www.youtube.com/watch?v=SBslu6S9Rgw
# 66909        https://www.youtube.com/watch?v=_zRLuQwtru8
# 66924        https://www.youtube.com/watch?v=OKPvmQw7S7A
# 66927        https://www.youtube.com/watch?v=-jST4UlTTAU
# 66929        https://www.youtube.com/watch?v=0r92Wqxk7qA
# 66935        https://www.youtube.com/watch?v=4fUXozzvmHE
# 66943        https://www.youtube.com/watch?v=Zsq5qqiPk00
# 66948        https://www.youtube.com/watch?v=KB9bpL5Adhk
# 66952        https://www.youtube.com/watch?v=9hoeqj0dzHs
# 66955        https://www.youtube.com/watch?v=FKPsO6TUxPc
# 66968        https://www.youtube.com/watch?v=GnVV2_ebN5E
# 66972        https://www.youtube.com/watch?v=OMVHxaZvMNA
# 66979        https://www.youtube.com/watch?v=O_Q9kP_u6hw
# 66988        https://www.youtube.com/watch?v=Z1EoWufl_ss
#
#                                                     text
# 4      Hey!   It's Summer!   And it's my Birthday tod...
# 10     August Baby!! 🔥 Order your calendar today!! 💁🏽...
# 16     ✨ 25 Today. ✨ A year older. Should I also be a...
# 18     Today is my birthday! And I am celebrating wit...
# 19     Today is my birthday, and I am celebrating wit...
# 25     My birthday nails for today. @daily_charme Aur...
# 35     Lol, it actually is my birthday today, and I h...
# 56     It might not be my birthday until Thursday but...
# 64     I can't have almonds but I can definitely try ...
# 66     New post up on the blog about how I spent my b...
# 69     Só tenho a agradecer a linda vida que vivi ate...
# 71     I love that my birthday is also #NationalDogDa...
# 78     It's my birthday today 😱 #timeflies \nCan anyb...
# 80     As you might know, it's my birthday tomorrow a...
# 83     Today is my birthday! 🎉 Let's eat cookies for ...
# 86     Two weeks today I'll be back in Perth to spend...
# 92     It's my BIRTHDAY today 🎉🎉 I am headed to @catc...
# 93     Ron and Hermione sent me loads of gifts and sw...
# 100    It's International Lion Day today!! 🦁\nPretty ...
# 124    Eat Only When You're Hungry is my August @book...
# 176    Since today is my birthday I decided I wanted ...
# 185    OPEN ME FOR ALL OF THE THINGS!\n\nI talk about...
# 198    OMG!!! Today is NATIONAL PINEAPPLE DAY!!! Sooo...
# 214    That's right, today is my birthday! 🎊🎉🎁🎈Thank ...
# 217    It's not my birthday suit but it's close. Post...
# 233    RT @funder: For my birthday today, I’d love it...
# 257    No better way to spend my birthday!! 😁😁👌 Shopp...
# 258    Today is my birthday, and even though I'm 45.....
# 269    Making my favorite ice cream today... Aquafaba...
# 270    Today it's my Birthday ! ✌🏻🎂🎉Une année de plus...
# ...                                                  ...
# 66824  Good morning! I find that cleansers are the ea...
# 66837  LITTLE MIX X CNCO REGGAETON LENTO (Remix) REAC...
# 66839  HOMECOMING DRESS SHOPPING 2017! CRAZY Mom Pick...
# 66840  Today I decided to do a huge collective haul ,...
# 66844  ♥  CLICK HERE FOR MORE INFO  ♥\n\n\nTODAY IS M...
# 66853  Today is my birthday.\nLet’s be real. This yea...
# 66857  💙 today was perfect. #genderreveal #hereforthe...
# 66862  My answer to everything today is “it’s my birt...
# 66865  Its my Birthday and I’m making some of my favo...
# 66873  Hi friends!! Today I will be sharing 5 LIFE HA...
# 66874  Summer is here and so is my birthday season! H...
# 66879  Share your natural hair stories, goals and res...
# 66895  BACK TO SCHOOL SUPPLY SHOPPING W/ MY CRAZY MOM...
# 66899  *Subscribe Here* http://bit.ly/1U6GJFP Hi guys...
# 66901  Hi friends!! Today I am really excited to shar...
# 66902  OPEN FOR MORE INFO\n\nWHAT I GOT FOR MY BIRTHD...
# 66903  Today I decided to show you my 10 minute drugs...
# 66909  Beauty & The Beast Themed DIYS- Room decor, wa...
# 66924  Wow! Thats it! 5 Years has flown by wayyy to f...
# 66927  Hello Beautiful people!!!\n\nTodays video is a...
# 66929  HEY GUYS! Today I'm showing you how I made som...
# 66935  Today's video is my MARCH FAVORITES 2017. I ha...
# 66943  ******EXPAND******\n\n\nThank you for taking t...
# 66948  Hey guys, so my today was my birthday and I ju...
# 66952  Today I decided to show you my may 2017 try on...
# 66955  Today I decided to show talk about my honest o...
# 66968  Today I decided to show you the NEW iPhone X U...
# 66972  Get a free 30 day trial & download a free titl...
# 66979  REAL vs FAKE $4: Kylie Cosmetics Kylighter. To...
# 66988  Hello marzipans! Felix gifted me this Bug Make...
#
# [8964 rows x 5 columns]

# %%
# birthday mentions by channels

posts.groupby('channel').count().reset_index().sort_values('publish_date', ascending = False)
# looks like instagram has the most birthday posts, followed by tiwtter etc etc.

# maybe a way to further granularize. how many unique users in each channel, and of these users, what are the average blah blah
# Out:
#                                              channel  user_id  publish_date  \
# 2                                          INSTAGRAM    35029         35029
# 5                                            TWITTER    20433         20433
# 1                                           FACEBOOK     6021          6021
# 4                                          PINTEREST     3380          3380
# 6                                            YOUTUBE     2127          2127
# 0  Dm me if you want to negotiate. https://t.co/S...        0             0
# 3                Need gin for my birthday tomorrow 😢        0             0
#
#    post_link   text
# 2      35029  35029
# 5      20433  20433
# 1       6021   6021
# 4       3380   3380
# 6       2127   2127
# 0          0      0
# 3          0      0

# %% [markdown]
# What are some common themes in these birthday posts? (Are they about cake, gifts, resolutions, or something else?)
# how to figure out common themes, hash each word longer than idk 3 letters?
# yes very "common" words that pop out in these posts

# %% [markdown]
# Develop a way to guess a user’s birth date (month and/or day and/or year) using this text data.
#
# easy enough within a month, a user will likely not talk about the birthday unless its within a few weeks.. i hope
# within a day - if a user posts multiple times, then the last post is likely the birthday or CLOSE to the birthday.
#
#  so basically 1 - aggregate data per user id in some way.
#   and then start reading the text and publish date.
#
#   based on "data" guess the birthday
#
#   so a user will have
#   1- a list of publish dates
#   each publish date will be paired w/ a text
#   2- a list of texts
#   3- a platform/channel that the post on
#       -
#
#       so based on certain phrases, add (or possibly subtract) from the date.
#
#       from there "make a prediction"... based on a list of dates that have been... modified?
#
#  strategy - for a user, apply function that analyzes data and returns a best guess
#
# at each iteration
#
#     case 1 - date, nothing that i can take from the text
#         if theres a later date, simply use the latest date and assume its the birthday post.
#
#     case 2 - date, something that might indicate a date (in X days .. etc)
#         ways to predict a date from text
#
#         in X days <- how to parse this?
#
#     in [a-zA-Z\d]+ days   might need a numword dictionary to the the change. i should run this on data and see how many ppl mention.
#
#     in [a-zA-Z\d]+ days
#
#     **** UNTIL MY BIRTHDAY
#     since these posts all have my birthday, can look at the locality around the word birthday specifically also these ppl likely to be basic or sthn

# %%
# test zone
# find posts with in X days e.g.

# iterate thru list of users


unique_users = posts['user_id'].unique()

b = posts[posts['user_id']== unique_users[0]]['text']
print(b)

def in_x_days(text):

    for match in re.finditer('in [a-zA-Z\d]+ days', text):
        print(match)
    
for user in unique_users:
    user_row = posts[posts['user_id']== user]['text']
    for text in user_row:
        in_x_days(text)
        
        
        
    
# for user in unique_users:
#     posts[]
# posts['user_id' ]


    

    
    # setup a dictionary if needbe
    # how to capture a section in between
